# %% [markdown]
# This is notebook aims to create a minimum framework of RL custom environment
#
# [gymnasium custom environment](https://gymnasium.farama.org/tutorials/gymnasium_basics/environment_creation/#sphx-glr-tutorials-gymnasium-basics-environment-creation-py)

# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.env_checker import check_env

# %%
class minimumTradeEnv(gym.Env):
    def __init__(self):
        self.observation_space = gym.spaces.Discrete(2) # {0, 1}
        self.action_space = gym.spaces.Discrete(2) # {0, 1}

    def _get_obs(self):
        return np.random.randint(2) # {0, 1}
    
    def reset(self, seed=None):
        # super().reset(seed=seed)
        self.observation = self._get_obs()
        info = {}
        return self.observation, info

    def step(self, action):
        self.signal = self.observation
        self.action = action
        self.observation = self._get_obs()
        terminated = False
        truncated = False
        self.reward = 1 if self.action==self.signal else 0
        info = {}

        return self.observation, self.reward, terminated, truncated, info
    
    def render(self):
        print(f"signal: {self.signal}, action: {self.action}, reward:{self.reward}")

# %%
env = minimumTradeEnv()
check_env(env)

# %%
model_ppo = PPO("MlpPolicy", env, verbose=1, gamma=1, batch_size = 256)
model_ppo.learn(total_timesteps=50000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 2366 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1964        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.021711282 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | -0.00761    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.2        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0308     |
# |    value_loss           | 90.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1822        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.025000311 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.000391    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0279     |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1812        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018289654 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | -0.00641    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 152         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1779        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012313526 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | 0.00079     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 201         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1751         |
# |    iterations           | 6            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0078076893 |
# |    clip_fraction        | 0.0933       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.38        |
# |    explained_variance   | -0.00107     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 101          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0146      |
# |    value_loss           | 240          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1745         |
# |    iterations           | 7            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0050445865 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.311       |
# |    explained_variance   | 0.000942     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 122          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 283          |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1740      |
# |    iterations           | 8         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0043264 |
# |    clip_fraction        | 0.0497    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.247    |
# |    explained_variance   | -0.000398 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 133       |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.00962  |
# |    value_loss           | 298       |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1725         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0030919963 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.195       |
# |    explained_variance   | -0.00073     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 141          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00686     |
# |    value_loss           | 314          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1718         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0025164026 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.151       |
# |    explained_variance   | 2.87e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 148          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00719     |
# |    value_loss           | 327          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1719        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.001251129 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.119      |
# |    explained_variance   | 0.000373    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 154         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 339         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1718          |
# |    iterations           | 12            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00076076674 |
# |    clip_fraction        | 0.00972       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0961       |
# |    explained_variance   | -0.000275     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 156           |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00242      |
# |    value_loss           | 346           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1718          |
# |    iterations           | 13            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00038642032 |
# |    clip_fraction        | 0.00186       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0804       |
# |    explained_variance   | -0.000269     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 161           |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00106      |
# |    value_loss           | 352           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1717          |
# |    iterations           | 14            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00054448313 |
# |    clip_fraction        | 0.00615       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0635       |
# |    explained_variance   | 4.86e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 161           |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00211      |
# |    value_loss           | 351           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1716          |
# |    iterations           | 15            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00013734514 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0541       |
# |    explained_variance   | 6.78e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 165           |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000544     |
# |    value_loss           | 357           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1718          |
# |    iterations           | 16            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00035987044 |
# |    clip_fraction        | 0.00479       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0429       |
# |    explained_variance   | -5.48e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 163           |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.0015       |
# |    value_loss           | 355           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1721          |
# |    iterations           | 17            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00021046933 |
# |    clip_fraction        | 0.00146       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0364       |
# |    explained_variance   | -3.87e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 165           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000637     |
# |    value_loss           | 357           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1724          |
# |    iterations           | 18            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00020141667 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0295       |
# |    explained_variance   | 0.000141      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 165           |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00123      |
# |    value_loss           | 359           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1726          |
# |    iterations           | 19            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00011595263 |
# |    clip_fraction        | 0.00107       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0241       |
# |    explained_variance   | 7.95e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 166           |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000896     |
# |    value_loss           | 361           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1729        |
# |    iterations           | 20          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 3.51746e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0209     |
# |    explained_variance   | 8.71e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 166         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00022    |
# |    value_loss           | 361         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1731          |
# |    iterations           | 21            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 1.2314849e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0185       |
# |    explained_variance   | -7.19e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 165           |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000103     |
# |    value_loss           | 362           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1733          |
# |    iterations           | 22            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00015095083 |
# |    clip_fraction        | 0.00137       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0159       |
# |    explained_variance   | 7.93e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 163           |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000598     |
# |    value_loss           | 360           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1735          |
# |    iterations           | 23            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 5.8646256e-05 |
# |    clip_fraction        | 0.00083       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0131       |
# |    explained_variance   | 8.64e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 166           |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000866     |
# |    value_loss           | 362           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1735          |
# |    iterations           | 24            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 1.7078419e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.012        |
# |    explained_variance   | -7.52e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 167           |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -2.35e-05     |
# |    value_loss           | 363           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1730          |
# |    iterations           | 25            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 5.0811912e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0109       |
# |    explained_variance   | -2.91e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 166           |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00018      |
# |    value_loss           | 362           |
# -------------------------------------------

# %%
obs, _ = env.reset()

for i in range(20):
    env.render()
    action, _states = model_ppo.predict(obs)
    obs, rewards, terminated, truncated, info = env.step(action)
# Out:
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 1, action: 1, reward:1
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
