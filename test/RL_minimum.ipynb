# %% [markdown]
# This is notebook aims to create a minimum framework of RL custom environment
#
# [gymnasium custom environment](https://gymnasium.farama.org/tutorials/gymnasium_basics/environment_creation/#sphx-glr-tutorials-gymnasium-basics-environment-creation-py)

# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.env_checker import check_env

# %% [markdown]
# # 1. Create a Custom Env

# %%
class minimumTradeEnv(gym.Env):
    def __init__(self):
        self.observation_space = gym.spaces.Discrete(2) # {0, 1}
        self.action_space = gym.spaces.Discrete(2) # {0, 1}

    def _get_obs(self):
        return np.random.randint(2) # {0, 1}
    
    def reset(self, seed=None):
        # super().reset(seed=seed)
        self.observation = self._get_obs()
        return self.observation, {}

    def step(self, action):
        self.signal = self.observation
        self.action = action
        self.observation = self._get_obs()
        terminated = False
        truncated = False
        self.reward = 1 if self.action==self.signal else 0

        return self.observation, self.reward, terminated, truncated, {}
    
    def render(self):
        print(f"signal: {self.signal}, action: {self.action}, reward:{self.reward}")

# %% [markdown]
# # 2. Verify the Custom Env

# %%
env = minimumTradeEnv()
check_env(env)

# %% [markdown]
# # 3. Train the Model

# %%
model_ppo = PPO("MlpPolicy", env, verbose=1, gamma=1, batch_size = 256)
model_ppo.learn(total_timesteps=50000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 472  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.021635562 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | -0.000255   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0309     |
# |    value_loss           | 76.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.024570785 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.000588    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0292     |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 560         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016177386 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | -0.000778   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 5           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010421287 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | -0.000504   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 208         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 6           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008772707 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | -1.43e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 229         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 7            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0047985213 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.317       |
# |    explained_variance   | 2.55e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 119          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00939     |
# |    value_loss           | 280          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 8           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004117023 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | -4.21e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 130         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0091     |
# |    value_loss           | 291         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 9           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002867245 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.203      |
# |    explained_variance   | 5.72e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 143         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00711    |
# |    value_loss           | 316         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 10           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0020103373 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.162       |
# |    explained_variance   | -4.41e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 146          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 325          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 11           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0013213604 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.129       |
# |    explained_variance   | 1.61e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 152          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 337          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 12            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00083325023 |
# |    clip_fraction        | 0.00869       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.105        |
# |    explained_variance   | -2.72e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 158           |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00221      |
# |    value_loss           | 344           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 13           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0006548255 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.085       |
# |    explained_variance   | -7.87e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 158          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 349          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 598           |
# |    iterations           | 14            |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00061809755 |
# |    clip_fraction        | 0.0061        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0678       |
# |    explained_variance   | -2.15e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 159           |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00185      |
# |    value_loss           | 350           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 15            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00025785618 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0559       |
# |    explained_variance   | -2.74e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 163           |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000847     |
# |    value_loss           | 355           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 610           |
# |    iterations           | 16            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00023264921 |
# |    clip_fraction        | 0.00151       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0462       |
# |    explained_variance   | 8.94e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 162           |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000854     |
# |    value_loss           | 356           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 614           |
# |    iterations           | 17            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00016978616 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0384       |
# |    explained_variance   | 1.61e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 165           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000665     |
# |    value_loss           | 358           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 18          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 3.65203e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0325     |
# |    explained_variance   | -8.23e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 164         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000265   |
# |    value_loss           | 361         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 620           |
# |    iterations           | 19            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 3.3069082e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0285       |
# |    explained_variance   | 5.78e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 165           |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000224     |
# |    value_loss           | 361           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 623          |
# |    iterations           | 20           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 2.151227e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0255      |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 165          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000131    |
# |    value_loss           | 361          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 21           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 4.979936e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0225      |
# |    explained_variance   | -2.98e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 167          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000265    |
# |    value_loss           | 361          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 628           |
# |    iterations           | 22            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 1.4604535e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0199       |
# |    explained_variance   | -1.56e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 166           |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -9.38e-05     |
# |    value_loss           | 362           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 630           |
# |    iterations           | 23            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 4.8885675e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0179       |
# |    explained_variance   | 3.34e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 165           |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000235     |
# |    value_loss           | 361           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 632           |
# |    iterations           | 24            |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 3.6364072e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0156       |
# |    explained_variance   | 2.68e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 166           |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000178     |
# |    value_loss           | 362           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 634           |
# |    iterations           | 25            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 2.6251742e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0138       |
# |    explained_variance   | -8.46e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 166           |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000152     |
# |    value_loss           | 362           |
# -------------------------------------------

# %% [markdown]
# # 4. Instantiate a Test Env

# %%
test_env = minimumTradeEnv()

# %% [markdown]
# # 5. Test Env with Trained Model

# %%
obs, _ = test_env.reset()

for i in range(20):
    action, _states = model_ppo.predict(obs)
    obs, rewards, terminated, truncated, info = test_env.step(action)
    test_env.render()
# Out:
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 0, action: 0, reward:1
# signal: 1, action: 1, reward:1
# signal: 1, action: 1, reward:1
# signal: 1, action: 1, reward:1
# signal: 1, action: 1, reward:1
