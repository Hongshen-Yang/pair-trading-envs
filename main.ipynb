# %%
import pandas as pd
from utils.gridsearch import gridsearch
from utils.read2df import read2df
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint

import backtrader as bt
from itertools import combinations

# %%
symbols = ['BTCUSDT', 'ETHUSDT']

freqs = {'1m': 1, '3m': 3, '5m': 5, '15m': 15, '30m': 30, '1h':60, '2h': 120}

# %% [markdown]
# # Download Data from [binance-public-data](https://github.com/binance/binance-public-data/tree/master/python)
#
# Download BTCUSDT and ETHUSDT for all available history for intervals of 1m, 3m, 5m, 15m, 30m

# %%
# %%capture
# !python binance-public-data/python/download-kline.py -t spot -s BTCUSDT ETHUSDT -i 1m 3m 5m 15m 30m 1h 2h -skip-daily 1

# %% [markdown]
# # Read Downloaded Data
#
# The downloaded data can be found in `binance-public-data/data/`

# %%
dfs = read2df(symbols, freqs)

# %%
# I want to operate on:

FREQUENCY = '2h'
f = list(freqs.keys()).index(FREQUENCY)
dfs[f]
# Out:
#                 time      open      high       low     close        volume  \
# 0      1502949599999   4261.48   4328.69   4261.32   4315.32     70.415925
# 1      1502949599999    301.13    303.28    298.00    303.10    503.341230
# 2      1502956799999   4330.29   4349.99   4287.41   4349.99     11.672940
# 3      1502956799999    302.40    307.96    301.90    307.96   1058.611820
# 4      1502963999999   4333.32   4445.78   4333.32   4444.00     11.736430
# ...              ...       ...       ...       ...       ...           ...
# 52769  1693511999999   1660.16   1664.63   1645.00   1657.12  33238.020600
# 52770  1693519199999  26162.79  26194.86  25655.01  26024.57   7002.831350
# 52771  1693519199999   1657.12   1657.36   1630.00   1647.68  46938.519300
# 52772  1693526399999  26024.57  26072.73  25912.01  25940.78   2197.697860
# 52773  1693526399999   1647.68   1649.96   1644.02   1645.76  14284.954400
#
#            tic itvl                datetime
# 0      BTCUSDT   2h 2017-08-17 05:59:59.999
# 1      ETHUSDT   2h 2017-08-17 05:59:59.999
# 2      BTCUSDT   2h 2017-08-17 07:59:59.999
# 3      ETHUSDT   2h 2017-08-17 07:59:59.999
# 4      BTCUSDT   2h 2017-08-17 09:59:59.999
# ...        ...  ...                     ...
# 52769  ETHUSDT   2h 2023-08-31 19:59:59.999
# 52770  BTCUSDT   2h 2023-08-31 21:59:59.999
# 52771  ETHUSDT   2h 2023-08-31 21:59:59.999
# 52772  BTCUSDT   2h 2023-08-31 23:59:59.999
# 52773  ETHUSDT   2h 2023-08-31 23:59:59.999
#
# [52774 rows x 9 columns]

# %% [markdown]
# # Check Cointegration and Correlation

# %%
for comb in combinations(set(dfs[f]['tic']), 2):
    first_ele = dfs[f][dfs[f]['tic']==comb[0]]['close']
    second_ele = dfs[f][dfs[f]['tic']==comb[1]]['close']
    _, pvalue, _ = coint(first_ele, second_ele)
    if pvalue <= 0.05:
        print(f"{comb[0]} and {comb[1]} are cointegrated under {FREQUENCY} interval")
    else:
        print(f"{comb[0]} and {comb[1]} are not cointegrated under {FREQUENCY} interval")
# Out:
# ETHUSDT and BTCUSDT are not cointegrated under 2h interval

# %% [markdown]
# # Define Trading Strategy

# %%
class PairTrading(bt.Strategy):
    params = dict(
        OPEN_THRE=2,
        CLOS_THRE=0.1,
        period=30
    )

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status == order.Completed:
            if order.isbuy():
                print(f"Buy {order.data._name} @ price: {order.executed.price} for Qty: {order.executed.size}")
            else:
                print(f"Sell {order.data._name} @ price: {order.executed.price} for Qty: {order.executed.size}")

        elif order.status in [order.Expired, order.Canceled, order.Margin]:
            print('%s ,' % order.Status[order.status])
            pass

    def __init__(self):
        self.data0 = self.datas[0]
        self.data1 = self.datas[1]

        # Calculate zscore of the ratio
        self.transform = bt.indicators.OLS_TransformationN(
            self.data1, self.data0, period=self.p.period
        )
        self.zscore = self.transform.zscore

        # -1 for short data1/data0, 1 for long data1/data0, 0 for no position
        self.position_status = 0

    def next(self):
        # print(f'Right now the zscore is {self.transform.zscore[0]}, and the position is {self.position_status}')
        
        # Calculate the ratio between the 2 assets
        ratio = self.data1.close[0] / self.data0.close[0]

        if abs(self.zscore[0]) < self.p.CLOS_THRE and self.position_status != 0:
            print("------")
            print("close position")
            self.position_status = 0
            self.close(data=self.data0)
            self.close(data=self.data1)
    
        elif self.zscore[0] < -self.p.OPEN_THRE and self.position_status == 0:
            print("------")
            print(f"long {self.data0.alias} and short {self.data1.alias}")
            self.position_status = 1
            self.sell(data=self.data0, size=ratio)
            self.buy(data=self.data1, size=1)

        elif self.zscore[0] > self.p.OPEN_THRE and self.position_status == 0:
            print("------")
            print(f"long {self.data1.alias} and short {self.data0.alias}")
            self.position_status = -1

            self.sell(data=self.data0, size=ratio)
            self.buy(data=self.data1, size=1)

    def stop(self):
        print('==================================================')
        print('Starting Value - %.2f' % self.broker.startingcash)
        print('Ending   Value - %.2f' % self.broker.getvalue())
        print('==================================================')

# %% [markdown]
# # Execute the Strategy
#
# Load the data

# %%
datafeeds_eth = []
datafeeds_btc = []

for idx, freq in enumerate(freqs):
    datafeeds_eth.append(
        bt.feeds.PandasData(
            dataname=dfs[idx][dfs[idx]['tic']=='ETHUSDT'],
            datetime='datetime',
            open='open',
            high='high',
            low='low',
            close='close',
            volume='volume',
            openinterest=None
        )
    )
    datafeeds_btc.append(
        bt.feeds.PandasData(
            dataname=dfs[idx][dfs[idx]['tic']=='BTCUSDT'],
            datetime='datetime',
            open='open',
            high='high',
            low='low',
            close='close',
            volume='volume',
            openinterest=None
        )
    )
    print(freq)
# Out:
# 1m
# 3m
# 5m
# 15m
# 30m
# 1h
# 2h

# %% [markdown]
# The main strategy engine

# %%
datafeed0 = datafeeds_eth[f]
datafeed1 = datafeeds_btc[f]
datafeeds = [datafeed0, datafeed1]
param = {'OPEN_THRE':1, 'CLOS_THRE':0.1, 'period':30}

def cerebro_run(datafeeds, param):
    # Create a Cerebro instance and add the data feed
    cerebro = bt.Cerebro()
    cerebro.adddata(datafeeds[0], name='eth')
    cerebro.adddata(datafeeds[1], name='btc')

    # Set up other parameters for your backtest
    cerebro.broker.set_cash(100000)  # Set initial capital
    cerebro.broker.setcommission(commission=0.001)  # Set commission rate

    # cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='timereturns')
    cerebro.addanalyzer(bt.analyzers.Returns, _name='Returns')

    cerebro.addstrategy(PairTrading, **param)
    strats = cerebro.run()
    return strats

# cerebro_run(datafeeds, param)

# %% [markdown]
# # Grid Search the Strategy
# Define scoring and param_grid

# %%
param_grid = {
    'OPEN_THRE':[1, 2], 
    'CLOS_THRE':[0.1], 
    'period':[30]
}

def scoring(strats):
    score = strats[0].analyzers.Returns.get_analysis()['rtot']
    return score

# %% [markdown]
# Grid Searching

# %%
gridsearch(cerebro_run, param_grid, scoring, datafeeds)
# Out:
# ------
# long () and short ()
# Sell eth @ price: 294.25 for Qty: -13.848709996250978
# Buy btc @ price: 4096.32 for Qty: 1
# ------
# close position
# Buy eth @ price: 296.88000000000005 for Qty: 13.848709996250978
# Sell btc @ price: 4129.32 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 299.1 for Qty: -13.661952524239384
# Buy btc @ price: 4069.13 for Qty: 1
# ------
# close position
# Buy eth @ price: 332.12 for Qty: 13.661952524239384
# Sell btc @ price: 3997.57 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 309.96 for Qty: -11.936639029583507
# Buy btc @ price: 3700.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 311.16 for Qty: 11.936639029583507
# Sell btc @ price: 3866.48 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 307.08 for Qty: -12.76862706786505
# Buy btc @ price: 3874.38 for Qty: 1
# ------
# close position
# Buy eth @ price: 318.48 for Qty: 12.76862706786505
# Sell btc @ price: 4166.27 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 323.42 for Qty: -13.34490755055346
# Buy btc @ price: 4316.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 330.29 for Qty: 13.34490755055346
# Sell btc @ price: 4317.81 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 332.89000000000004 for Qty: -12.987951807228916
# Buy btc @ price: 4303.82 for Qty: 1
# ------
# close position
# Buy eth @ price: 328.45 for Qty: 12.987951807228916
# Sell btc @ price: 4319.7 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 327.69 for Qty: -13.04537825383747
# Buy btc @ price: 4289.12 for Qty: 1
# ------
# close position
# Buy eth @ price: 341.83 for Qty: 13.04537825383747
# Sell btc @ price: 4317.2 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 341.84 for Qty: -12.70131281388587
# Buy btc @ price: 4324.64 for Qty: 1
# ------
# close position
# Buy eth @ price: 362.0 for Qty: 12.70131281388587
# Sell btc @ price: 4367.4 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 364.36 for Qty: -12.570330725950322
# Buy btc @ price: 4581.61 for Qty: 1
# ------
# close position
# Buy eth @ price: 373.0 for Qty: 12.570330725950322
# Sell btc @ price: 4600.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 367.15 for Qty: -12.257623410365104
# Buy btc @ price: 4502.17 for Qty: 1
# ------
# close position
# Buy eth @ price: 379.78 for Qty: 12.257623410365104
# Sell btc @ price: 4584.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 385.82 for Qty: -12.01969438851892
# Buy btc @ price: 4674.97 for Qty: 1
# ------
# close position
# Buy eth @ price: 389.47999999999996 for Qty: 12.01969438851892
# Sell btc @ price: 4715.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 389.55999999999995 for Qty: -12.254901960784315
# Buy btc @ price: 4775.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 390.0 for Qty: 12.254901960784315
# Sell btc @ price: 4760.01 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 388.58 for Qty: -12.44635226278124
# Buy btc @ price: 4796.16 for Qty: 1
# ------
# close position
# Buy eth @ price: 351.59999999999997 for Qty: 12.44635226278124
# Sell btc @ price: 4604.01 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 341.72 for Qty: -13.052177221116702
# Buy btc @ price: 4465.12 for Qty: 1
# ------
# close position
# Buy eth @ price: 329.35 for Qty: 13.052177221116702
# Sell btc @ price: 4351.02 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 344.27 for Qty: -13.012384080932586
# Buy btc @ price: 4500.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 339.29 for Qty: 13.012384080932586
# Sell btc @ price: 4505.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 284.51 for Qty: -15.224755463437694
# Buy btc @ price: 4102.05 for Qty: 1
# ------
# close position
# Buy eth @ price: 310.2 for Qty: 15.224755463437694
# Sell btc @ price: 4336.86 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 286.35 for Qty: -14.324147207946746
# Buy btc @ price: 4153.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 299.04 for Qty: 14.324147207946746
# Sell btc @ price: 4187.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 242.01 for Qty: -14.958677685950413
# Buy btc @ price: 3659.5 for Qty: 1
# ------
# close position
# Buy eth @ price: 273.72 for Qty: 14.958677685950413
# Sell btc @ price: 3966.83 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 295.79 for Qty: -14.34833434691533
# Buy btc @ price: 4248.64 for Qty: 1
# ------
# close position
# Buy eth @ price: 318.71 for Qty: 14.34833434691533
# Sell btc @ price: 4442.09 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 320.31 for Qty: -14.005870718613632
# Buy btc @ price: 4476.13 for Qty: 1
# ------
# close position
# Buy eth @ price: 329.06 for Qty: 14.005870718613632
# Sell btc @ price: 4519.47 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 328.57 for Qty: -13.927372429550648
# Buy btc @ price: 4580.78 for Qty: 1
# ------
# close position
# Buy eth @ price: 329.56999999999994 for Qty: 13.927372429550648
# Sell btc @ price: 4625.36 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 292.02 for Qty: -14.699965313909122
# Buy btc @ price: 4243.78 for Qty: 1
# ------
# close position
# Buy eth @ price: 300.83 for Qty: 14.699965313909122
# Sell btc @ price: 4331.82 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 285.67 for Qty: -14.261132906600592
# Buy btc @ price: 4144.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 282.0 for Qty: 14.261132906600592
# Sell btc @ price: 4047.49 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 281.8 for Qty: -14.627043037613303
# Buy btc @ price: 4069.43 for Qty: 1
# ------
# close position
# Buy eth @ price: 291.04 for Qty: 14.627043037613303
# Sell btc @ price: 4162.49 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 298.27 for Qty: -14.046822742474916
# Buy btc @ price: 4200.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 307.55 for Qty: 14.046822742474916
# Sell btc @ price: 4325.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 278.55 for Qty: -14.158874131663248
# Buy btc @ price: 3914.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 238.42999999999998 for Qty: 14.158874131663248
# Sell btc @ price: 3481.02 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 234.22 for Qty: -14.388182051063103
# Buy btc @ price: 3368.73 for Qty: 1
# ------
# close position
# Buy eth @ price: 203.0 for Qty: 14.388182051063103
# Sell btc @ price: 2917.07 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 233.0 for Qty: -14.694393422548762
# Buy btc @ price: 3389.9 for Qty: 1
# ------
# close position
# Buy eth @ price: 248.0 for Qty: 14.694393422548762
# Sell btc @ price: 3674.98 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 252.26 for Qty: -14.85686481226178
# Buy btc @ price: 3664.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 242.09999999999997 for Qty: 14.85686481226178
# Sell btc @ price: 3559.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 241.27 for Qty: -14.408787679130292
# Buy btc @ price: 3499.03 for Qty: 1
# ------
# close position
# Buy eth @ price: 262.21 for Qty: 14.408787679130292
# Sell btc @ price: 3700.13 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 268.78 for Qty: -13.913690476190476
# Buy btc @ price: 3740.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 296.0 for Qty: 13.913690476190476
# Sell btc @ price: 4060.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 279.65 for Qty: -14.189394758660466
# Buy btc @ price: 3880.06 for Qty: 1
# ------
# close position
# Buy eth @ price: 289.0 for Qty: 14.189394758660466
# Sell btc @ price: 3960.01 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 278.0 for Qty: -13.742892857142857
# Buy btc @ price: 3870.3 for Qty: 1
# ------
# close position
# Buy eth @ price: 280.02 for Qty: 13.742892857142857
# Sell btc @ price: 3875.91 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 285.0 for Qty: -13.632385964912281
# Buy btc @ price: 3885.23 for Qty: 1
# ------
# close position
# Buy eth @ price: 283.43 for Qty: 13.632385964912281
# Sell btc @ price: 3859.53 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 258.0 for Qty: -14.046653696498053
# Buy btc @ price: 3592.84 for Qty: 1
# ------
# close position
# Buy eth @ price: 263.32 for Qty: 14.046653696498053
# Sell btc @ price: 3658.46 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 254.88 for Qty: -13.889055768546699
# Buy btc @ price: 3527.97 for Qty: 1
# ------
# close position
# Buy eth @ price: 281.3 for Qty: 13.889055768546699
# Sell btc @ price: 3766.41 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 283.5 for Qty: -13.055370671953552
# Buy btc @ price: 3691.45 for Qty: 1
# ------
# close position
# Buy eth @ price: 285.0 for Qty: 13.055370671953552
# Sell btc @ price: 3665.68 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 285.02 for Qty: -13.146642366465723
# Buy btc @ price: 3750.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 296.67 for Qty: 13.146642366465723
# Sell btc @ price: 3950.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 291.51 for Qty: -13.376433427178466
# Buy btc @ price: 3896.02 for Qty: 1
# ------
# close position
# Buy eth @ price: 289.14 for Qty: 13.376433427178466
# Sell btc @ price: 3891.03 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 299.84 for Qty: -13.693585107807687
# Buy btc @ price: 4099.8 for Qty: 1
# ------
# close position
# Buy eth @ price: 306.89 for Qty: 13.693585107807687
# Sell btc @ price: 4178.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 308.42 for Qty: -13.733766233766234
# Buy btc @ price: 4239.99 for Qty: 1
# ------
# close position
# Buy eth @ price: 280.0 for Qty: 13.733766233766234
# Sell btc @ price: 4000.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 297.01 for Qty: -14.208309484529142
# Buy btc @ price: 4234.99 for Qty: 1
# ------
# close position
# Buy eth @ price: 302.03000000000003 for Qty: 14.208309484529142
# Sell btc @ price: 4286.82 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 304.01 for Qty: -14.371172000921021
# Buy btc @ price: 4343.18 for Qty: 1
# ------
# close position
# Buy eth @ price: 301.41 for Qty: 14.371172000921021
# Sell btc @ price: 4336.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 300.03 for Qty: -14.349143390440638
# Buy btc @ price: 4305.03 for Qty: 1
# ------
# close position
# Buy eth @ price: 300.35 for Qty: 14.349143390440638
# Sell btc @ price: 4337.01 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 300.21 for Qty: -14.322796615815067
# Buy btc @ price: 4290.17 for Qty: 1
# ------
# close position
# Buy eth @ price: 303.93999999999994 for Qty: 14.322796615815067
# Sell btc @ price: 4400.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 302.89 for Qty: -14.652601690438456
# Buy btc @ price: 4410.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 297.5 for Qty: 14.652601690438456
# Sell btc @ price: 4410.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 299.41 for Qty: -14.635037708893982
# Buy btc @ price: 4405.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 287.93000000000006 for Qty: 14.635037708893982
# Sell btc @ price: 4271.97 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 290.13 for Qty: -14.54680039844743
# Buy btc @ price: 4235.02 for Qty: 1
# ------
# close position
# Buy eth @ price: 294.78 for Qty: 14.54680039844743
# Sell btc @ price: 4318.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 303.75 for Qty: -14.287182866556837
# Buy btc @ price: 4377.91 for Qty: 1
# ------
# close position
# Buy eth @ price: 309.87 for Qty: 14.287182866556837
# Sell btc @ price: 4359.9 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 311.08 for Qty: -14.221407671779042
# Buy btc @ price: 4425.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 300.01 for Qty: 14.221407671779042
# Sell btc @ price: 4684.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 297.17 for Qty: -16.134950186172887
# Buy btc @ price: 4809.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 299.86 for Qty: 16.134950186172887
# Sell btc @ price: 4839.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 303.0 for Qty: -16.02506331612012
# Buy btc @ price: 4850.42 for Qty: 1
# ------
# close position
# Buy eth @ price: 328.03 for Qty: 16.02506331612012
# Sell btc @ price: 5745.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 346.05 for Qty: -16.42939389555909
# Buy btc @ price: 5678.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 341.91 for Qty: 16.42939389555909
# Sell btc @ price: 5720.02 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 323.1 for Qty: -17.086939028164654
# Buy btc @ price: 5520.81 for Qty: 1
# ------
# close position
# Buy eth @ price: 321.26 for Qty: 17.086939028164654
# Sell btc @ price: 5579.89 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 322.38 for Qty: -17.538794715193816
# Buy btc @ price: 5624.95 for Qty: 1
# ------
# close position
# Buy eth @ price: 302.98 for Qty: 17.538794715193816
# Sell btc @ price: 5355.13 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 306.44 for Qty: -17.91932904741703
# Buy btc @ price: 5490.54 for Qty: 1
# ------
# close position
# Buy eth @ price: 306.0 for Qty: 17.91932904741703
# Sell btc @ price: 5664.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 305.98 for Qty: -19.276681394207166
# Buy btc @ price: 5889.99 for Qty: 1
# ------
# close position
# Buy eth @ price: 302.97 for Qty: 19.276681394207166
# Sell btc @ price: 6030.53 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 296.02 for Qty: -19.92136352865509
# Buy btc @ price: 5879.98 for Qty: 1
# ------
# close position
# Buy eth @ price: 292.62 for Qty: 19.92136352865509
# Sell btc @ price: 5898.97 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 282.27 for Qty: -21.04639083567541
# Buy btc @ price: 5909.47 for Qty: 1
# ------
# close position
# Buy eth @ price: 307.65 for Qty: 21.04639083567541
# Sell btc @ price: 5633.04 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 296.99 for Qty: -18.350853564093068
# Buy btc @ price: 5479.98 for Qty: 1
# ------
# close position
# Buy eth @ price: 286.67 for Qty: 18.350853564093068
# Sell btc @ price: 5364.98 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 298.12 for Qty: -18.76229453203623
# Buy btc @ price: 5593.04 for Qty: 1
# ------
# close position
# Buy eth @ price: 295.53 for Qty: 18.76229453203623
# Sell btc @ price: 5904.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 296.21 for Qty: -19.723304412410116
# Buy btc @ price: 5842.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 294.92 for Qty: 19.723304412410116
# Sell btc @ price: 5819.68 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 292.97 for Qty: -19.38860634194627
# Buy btc @ price: 5680.27 for Qty: 1
# ------
# close position
# Buy eth @ price: 305.87 for Qty: 19.38860634194627
# Sell btc @ price: 5790.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price:
0 for Qty: 1
# ------
# close position
# Buy eth @ price: 986.01 for Qty: 16.070724568424826
# Sell btc @ price: 14648.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 993.98 for Qty: -16.0105558188069
# Buy btc @ price: 15873.5 for Qty: 1
# ------
# close position
# Buy eth @ price: 993.73 for Qty: 16.0105558188069
# Sell btc @ price: 16500.18 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 983.2 for Qty: -16.444263628966638
# Buy btc @ price: 16159.69 for Qty: 1
# ------
# close position
# Buy eth @ price: 1123.09 for Qty: 16.444263628966638
# Sell btc @ price: 16218.85 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1096.99 for Qty: -13.502055261654164
# Buy btc @ price: 14650.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1133.18 for Qty: 13.502055261654164
# Sell btc @ price: 14902.54 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1138.4 for Qty: -12.338122352858475
# Buy btc @ price: 14072.87 for Qty: 1
# ------
# close position
# Buy eth @ price: 1201.51 for Qty: 12.338122352858475
# Sell btc @ price: 14655.01 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1271.98 for Qty: -10.838498695854314
# Buy btc @ price: 13750.6 for Qty: 1
# ------
# close position
# Buy eth @ price: 1220.23 for Qty: 10.838498695854314
# Sell btc @ price: 13650.01 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1385.64 for Qty: -10.168990703851263
# Buy btc @ price: 14086.64 for Qty: 1
# ------
# close position
# Buy eth @ price: 1003.0000000000001 for Qty: 10.168990703851263
# Sell btc @ price: 11060.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1028.03 for Qty: -10.910894454209112
# Buy btc @ price: 11246.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1074.5 for Qty: 10.910894454209112
# Sell btc @ price: 11962.44 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1109.08 for Qty: -10.985747747747748
# Buy btc @ price: 12194.18 for Qty: 1
# ------
# close position
# Buy eth @ price: 1049.0 for Qty: 10.985747747747748
# Sell btc @ price: 11530.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1035.54 for Qty: -10.84010840108401
# Buy btc @ price: 11240.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1055.29 for Qty: 10.84010840108401
# Sell btc @ price: 11184.7 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1055.7 for Qty: -10.68485365160557
# Buy btc @ price: 11280.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1008.99 for Qty: 10.68485365160557
# Sell btc @ price: 10510.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1018.0000000000001 for Qty: -10.361342474364514
# Buy btc @ price: 10549.09 for Qty: 1
# ------
# close position
# Buy eth @ price: 1069.0 for Qty: 10.361342474364514
# Sell btc @ price: 11232.33 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1064.0 for Qty: -10.339942013755314
# Buy btc @ price: 11018.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1173.0 for Qty: 10.339942013755314
# Sell btc @ price: 11905.7 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1264.11 for Qty: -9.501550289492835
# Buy btc @ price: 12001.94 for Qty: 1
# ------
# close position
# Buy eth @ price: 1111.1 for Qty: 9.501550289492835
# Sell btc @ price: 10130.39 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1125.96 for Qty: -9.143855406690909
# Buy btc @ price: 10285.1 for Qty: 1
# ------
# close position
# Buy eth @ price: 1079.07 for Qty: 9.143855406690909
# Sell btc @ price: 9326.23 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1012.0299999999999 for Qty: -8.835647164609746
# Buy btc @ price: 8937.86 for Qty: 1
# ------
# close position
# Buy eth @ price: 923.3 for Qty: 8.835647164609746
# Sell btc @ price: 8708.82 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 859.0000000000001 for Qty: -9.802048894062862
# Buy btc @ price: 8419.96 for Qty: 1
# ------
# close position
# Buy eth @ price: 821.6 for Qty: 9.802048894062862
# Sell btc @ price: 8179.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 828.03 for Qty: -9.787181623854208
# Buy btc @ price: 8104.07 for Qty: 1
# ------
# close position
# Buy eth @ price: 645.01 for Qty: 9.787181623854208
# Sell btc @ price: 6680.76 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price:
0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 677.61 for Qty: -13.60961319933295
# Buy btc @ price: 9222.02 for Qty: 1
# ------
# close position
# Buy eth @ price: 670.78 for Qty: 13.60961319933295
# Sell btc @ price: 9246.01 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 647.17 for Qty: -13.898960087766739
# Buy btc @ price: 8994.98 for Qty: 1
# ------
# close position
# Buy eth @ price: 650.68 for Qty: 13.898960087766739
# Sell btc @ price: 8926.07 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 671.02 for Qty: -13.53186986781121
# Buy btc @ price: 9080.02 for Qty: 1
# ------
# close position
# Buy eth @ price: 674.1000000000001 for Qty: 13.53186986781121
# Sell btc @ price: 9039.05 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 683.52 for Qty: -13.379076265855193
# Buy btc @ price: 9145.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 722.2 for Qty: 13.379076265855193
# Sell btc @ price: 9220.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 757.0 for Qty: -12.5063383071438
# Buy btc @ price: 9475.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 802.27 for Qty: 12.5063383071438
# Sell btc @ price: 9760.33 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 796.58 for Qty: -12.116980421686748
# Buy btc @ price: 9654.81 for Qty: 1
# ------
# close position
# Buy eth @ price: 812.05 for Qty: 12.116980421686748
# Sell btc @ price: 9839.71 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 819.5 for Qty: -12.0366076876144
# Buy btc @ price: 9863.99 for Qty: 1
# ------
# close position
# Buy eth @ price: 794.3000000000001 for Qty: 12.0366076876144
# Sell btc @ price: 9661.02 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 763.0 for Qty: -12.254259501965924
# Buy btc @ price: 9347.49 for Qty: 1
# ------
# close position
# Buy eth @ price: 758.81 for Qty: 12.254259501965924
# Sell btc @ price: 9351.77 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 736.98 for Qty: -12.634142706159725
# Buy btc @ price: 9319.99 for Qty: 1
# ------
# close position
# Buy eth @ price: 749.51 for Qty: 12.634142706159725
# Sell btc @ price: 9289.29 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 722.52 for Qty: -12.459447489342857
# Buy btc @ price: 9002.21 for Qty: 1
# ------
# close position
# Buy eth @ price: 677.6000000000001 for Qty: 12.459447489342857
# Sell btc @ price: 8594.98 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 681.43 for Qty: -12.573175021987685
# Buy btc @ price: 8575.21 for Qty: 1
# ------
# close position
# Buy eth @ price: 680.72 for Qty: 12.573175021987685
# Sell btc @ price: 8483.4 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 729.08 for Qty: -11.905017282054093
# Buy btc @ price: 8679.71 for Qty: 1
# ------
# close position
# Buy eth @ price: 727.49 for Qty: 11.905017282054093
# Sell btc @ price: 8663.37 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 690.7299999999999 for Qty: -11.907392646483384
# Buy btc @ price: 8216.22 for Qty: 1
# ------
# close position
# Buy eth @ price: 680.78 for Qty: 11.907392646483384
# Sell btc @ price: 8110.04 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 676.95 for Qty: -11.980190560602702
# Buy btc @ price: 8106.03 for Qty: 1
# ------
# close position
# Buy eth @ price: 684.63 for Qty: 11.980190560602702
# Sell btc @ price: 8155.85 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 690.74 for Qty: -11.841290509259258
# Buy btc @ price: 8184.7 for Qty: 1
# ------
# close position
# Buy eth @ price: 689.28 for Qty: 11.841290509259258
# Sell btc @ price: 8189.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 701.88 for Qty: -11.747806017779805
# Buy btc @ price: 8246.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 707.72 for Qty: 11.747806017779805
# Sell btc @ price: 8482.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price:
for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 472.0 for Qty: -13.501949152542373
# Buy btc @ price: 6372.92 for Qty: 1
# ------
# close position
# Buy eth @ price: 512.64 for Qty: 13.501949152542373
# Sell btc @ price: 6602.11 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 498.0 for Qty: -13.22344932832674
# Buy btc @ price: 6584.58 for Qty: 1
# ------
# close position
# Buy eth @ price: 490.11 for Qty: 13.22344932832674
# Sell btc @ price: 6406.18 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 499.91999999999996 for Qty: -13.045559088818223
# Buy btc @ price: 6518.32 for Qty: 1
# ------
# close position
# Buy eth @ price: 502.21 for Qty: 13.045559088818223
# Sell btc @ price: 6513.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 517.77 for Qty: -12.959667921614054
# Buy btc @ price: 6711.39 for Qty: 1
# ------
# close position
# Buy eth @ price: 536.24 for Qty: 12.959667921614054
# Sell btc @ price: 6730.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 500.04 for Qty: -13.001861675507957
# Buy btc @ price: 6499.76 for Qty: 1
# ------
# close position
# Buy eth @ price: 473.32 for Qty: 13.001861675507957
# Sell btc @ price: 6130.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 478.55 for Qty: -12.982175321283043
# Buy btc @ price: 6206.28 for Qty: 1
# ------
# close position
# Buy eth @ price: 464.22 for Qty: 12.982175321283043
# Sell btc @ price: 6051.95 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 436.71 for Qty: -13.344014648661021
# Buy btc @ price: 5829.08 for Qty: 1
# ------
# close position
# Buy eth @ price: 450.7 for Qty: 13.344014648661021
# Sell btc @ price: 6162.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 458.75 for Qty: -13.358721234309623
# Buy btc @ price: 6128.39 for Qty: 1
# ------
# close position
# Buy eth @ price: 459.04 for Qty: 13.358721234309623
# Sell btc @ price: 6252.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 429.81 for Qty: -14.13979596590115
# Buy btc @ price: 6065.89 for Qty: 1
# ------
# close position
# Buy eth @ price: 436.76 for Qty: 14.13979596590115
# Sell btc @ price: 6144.84 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 435.88 for Qty: -14.00273010920437
# Buy btc @ price: 6108.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 412.19 for Qty: 14.00273010920437
# Sell btc @ price: 5897.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 457.87 for Qty: -14.006204124432015
# Buy btc @ price: 6411.48 for Qty: 1
# ------
# close position
# ...
# ------
# close position
# Buy eth @ price: 1603.99 for Qty: 14.522436915260034
# Sell btc @ price: 23117.1 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1594.58 for Qty: -14.522363255528102
# Buy btc @ price: 23157.07 for Qty: 1
# ------
# close position
# Buy eth @ price: 1633.12 for Qty: 14.522363255528102
# Sell btc @ price: 23499.33 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1657.0 for Qty: -14.214597377203518
# Buy btc @ price: 23553.94 for Qty: 1
# ------
# close position
# Buy eth @ price: 1642.08 for Qty: 14.214597377203518
# Sell btc @ price: 23399.85 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1550.5 for Qty: -14.225256368913254
# Buy btc @ price: 22055.95 for Qty: 1
# ------
# close position
# Buy eth @ price: 1536.92 for Qty: 14.225256368913254
# Sell btc @ price: 21688.54 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1432.09 for Qty: -14.11466378046226
# Buy btc @ price: 20213.61 for Qty: 1
# ------
# close position
# Buy eth @ price: 1407.4200000000003 for Qty: 14.11466378046226
# Sell btc @ price: 19928.57 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1416.66 for Qty: -14.012501323544983
# Buy btc @ price: 19850.81 for Qty: 1
# ------
# close position
# Buy eth @ price: 1429.3 for Qty: 14.012501323544983
# Sell btc @ price: 20077.14 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1541.11 for Qty: -13.803208056478407
# Buy btc @ price: 21272.82 for Qty: 1
# ------
# close position
# Buy eth @ price: 1667.28 for Qty: 13.803208056478407
# Sell btc @ price: 24083.58 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1770.03 for Qty: -14.629509104365463
# Buy btc @ price: 25894.67 for Qty: 1
# ------
# close position
# Buy eth @ price: 1705.12 for Qty: 14.629509104365463
# Sell btc @ price: 24872.54 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1679.91 for Qty: -14.735523120148578
# Buy btc @ price: 24753.27 for Qty: 1
# ------
# close position
# Buy eth @ price: 1656.25 for Qty: 14.735523120148578
# Sell btc @ price: 24684.94 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1717.41 for Qty: -15.384410245660616
# Buy btc @ price: 26419.28 for Qty: 1
# ------
# close position
# Buy eth @ price: 1790.23 for Qty: 15.384410245660616
# Sell btc @ price: 27329.14 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1793.64 for Qty: -15.597204567248722
# Buy btc @ price: 27977.53 for Qty: 1
# ------
# close position
# Buy eth @ price: 1748.4 for Qty: 15.597204567248722
# Sell btc @ price: 27927.06 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1745.2 for Qty: -15.662951736467244
# Buy btc @ price: 27335.13 for Qty: 1
# ------
# close position
# Buy eth @ price: 1744.04 for Qty: 15.662951736467244
# Sell btc @ price: 27458.74 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1724.31 for Qty: -15.64381488140115
# Buy btc @ price: 26974.63 for Qty: 1
# ------
# close position
# Buy eth @ price: 1773.0 for Qty: 15.64381488140115
# Sell btc @ price: 27261.06 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1804.85 for Qty: -15.56177210420753
# Buy btc @ price: 28086.82 for Qty: 1
# ------
# close position
# Buy eth @ price: 1791.09 for Qty: 15.56177210420753
# Sell btc @ price: 28350.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1792.79 for Qty: -15.65623605533244
# Buy btc @ price: 28068.5 for Qty: 1
# ------
# close position
# Buy eth @ price: 1826.3 for Qty: 15.65623605533244
# Sell btc @ price: 28370.78 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1778.47 for Qty: -15.563698010087322
# Buy btc @ price: 27679.58 for Qty: 1
# ------
# close position
# Buy eth @ price: 1809.35 for Qty: 15.563698010087322
# Sell btc @ price: 28327.33 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1800.61 for Qty: -15.54277716995907
# Buy btc @ price: 27986.48 for Qty: 1
# ------
# close position
# Buy eth @ price: 1864.9 for Qty: 15.54277716995907
# Sell btc @ price: 28289.51 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1911.02 for Qty: -14.95086916934412
# Buy btc @ price: 28571.42 for Qty: 1
# ------
# close position
# Buy eth @ price: 1870.65 for Qty: 14.95086916934412
# Sell btc @ price: 27980.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1858.73 for Qty: -15.105894885217324
# Buy btc @ price: 28077.78 for Qty: 1
# ------
# close position
# Buy eth @ price: 1857.99 for Qty: 15.105894885217324
# Sell btc @ price: 28305.59 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1888.74 for Qty: -15.445860445908098
# Buy btc @ price: 29173.05 for Qty: 1
# ------
# close position
# Buy eth @ price: 2117.23 for Qty: 15.445860445908098
# Sell btc @ price: 30775.34 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 2058.34 for Qty: -14.690425294169087
# Buy btc @ price: 30237.88 for Qty: 1
# ------
# close position
# Buy eth @ price: 2107.34 for Qty: 14.690425294169087
# Sell btc @ price: 30459.94 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 2092.04 for Qty: -14.314294591429459
# Buy btc @ price: 29946.22 for Qty: 1
# ------
# close position
# Buy eth @ price: 2078.15 for Qty: 14.314294591429459
# Sell btc @ price: 29467.25 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 2117.8 for Qty: -14.345353668901689
# Buy btc @ price: 30380.59 for Qty: 1
# ------
# close position
# Buy eth @ price: 2091.46 for Qty: 14.345353668901689
# Sell btc @ price: 30211.23 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1861.83 for Qty: -15.240933699995704
# Buy btc @ price: 28376.19 for Qty: 1
# ------
# close position
# Buy eth @ price: 1953.92 for Qty: 15.240933699995704
# Sell btc @ price: 29820.02 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1881.43 for Qty: -15.37751072322648
# Buy btc @ price: 28931.71 for Qty: 1
# ------
# close position
# Buy eth @ price: 1891.02 for Qty: 15.37751072322648
# Sell btc @ price: 29272.65 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1894.18 for Qty: -15.527064338846683
# Buy btc @ price: 29411.21 for Qty: 1
# ------
# close position
# Buy eth @ price: 1863.7999999999997 for Qty: 15.527064338846683
# Sell btc @ price: 28542.06 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1868.02 for Qty: -15.162113693181514
# Buy btc @ price: 28322.97 for Qty: 1
# ------
# close position
# Buy eth @ price: 1985.22 for Qty: 15.162113693181514
# Sell btc @ price: 29486.79 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1865.38 for Qty: -15.117326671634348
# Buy btc @ price: 28199.72 for Qty: 1
# ------
# close position
# Buy eth @ price: 1847.55 for Qty: 15.117326671634348
# Sell btc @ price: 27668.8 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1759.48 for Qty: -14.954230535331662
# Buy btc @ price: 26311.51 for Qty: 1
# ------
# close position
# Buy eth @ price: 1795.12 for Qty: 14.954230535331662
# Sell btc @ price: 26775.27 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1816.87 for Qty: -14.911584694641363
# Buy btc @ price: 27092.55 for Qty: 1
# ------
# close position
# Buy eth @ price: 1823.81 for Qty: 14.911584694641363
# Sell btc @ price: 27060.05 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1828.1099999999997 for Qty: -14.980083146436192
# Buy btc @ price: 27385.09 for Qty: 1
# ------
# close position
# Buy eth @ price: 1807.99 for Qty: 14.980083146436192
# Sell btc @ price: 27086.78 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1814.67 for Qty: -14.833132194834322
# Buy btc @ price: 26917.24 for Qty: 1
# ------
# close position
# Buy eth @ price: 1812.31 for Qty: 14.833132194834322
# Sell btc @ price: 26880.26 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1817.72 for Qty: -14.941129546904914
# Buy btc @ price: 27158.79 for Qty: 1
# ------
# close position
# Buy eth @ price: 1816.99 for Qty: 14.941129546904914
# Sell btc @ price: 27055.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1809.49 for Qty: -14.82743108517364
# Buy btc @ price: 26829.93 for Qty: 1
# ------
# close position
# Buy eth @ price: 1793.96 for Qty: 14.82743108517364
# Sell btc @ price: 26584.17 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1777.15 for Qty: -14.699985932532426
# Buy btc @ price: 26124.08 for Qty: 1
# ------
# close position
# Buy eth @ price: 1812.26 for Qty: 14.699985932532426
# Sell btc @ price: 26463.29 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1829.89 for Qty: -14.675346605533665
# Buy btc @ price: 26854.28 for Qty: 1
# ------
# close position
# Buy eth @ price: 1890.43 for Qty: 14.675346605533665
# Sell btc @ price: 27666.7 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1903.19 for Qty: -14.347176830357611
# Buy btc @ price: 27305.27 for Qty: 1
# ------
# close position
# Buy eth @ price: 1884.25 for Qty: 14.347176830357611
# Sell btc @ price: 27047.14 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1891.82 for Qty: -14.31432694442389
# Buy btc @ price: 27080.12 for Qty: 1
# ------
# close position
# Buy eth @ price: 1737.39 for Qty: 14.31432694442389
# Sell btc @ price: 25628.81 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1760.16 for Qty: -14.783992455274205
# Buy btc @ price: 26022.34 for Qty: 1
# ------
# close position
# Buy eth @ price: 1736.4 for Qty: 14.783992455274205
# Sell btc @ price: 25772.8 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1666.81 for Qty: -15.343532517398607
# Buy btc @ price: 25574.6 for Qty: 1
# ------
# close position
# Buy eth @ price: 1670.5 for Qty: 15.343532517398607
# Sell btc @ price: 25595.96 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1722.18 for Qty: -15.31911693831691
# Buy btc @ price: 26382.43 for Qty: 1
# ------
# close position
# Buy eth @ price: 1744.62 for Qty: 15.31911693831691
# Sell btc @ price: 26593.58 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1724.25 for Qty: -15.474806291467544
# Buy btc @ price: 26682.29 for Qty: 1
# ------
# close position
# Buy eth @ price: 1728.78 for Qty: 15.474806291467544
# Sell btc @ price: 26780.57 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1732.49 for Qty: -15.626114009974142
# Buy btc @ price: 27071.94 for Qty: 1
# ------
# close position
# Buy eth @ price: 1769.07 for Qty: 15.626114009974142
# Sell btc @ price: 27796.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1829.65 for Qty: -15.81176727789468
# Buy btc @ price: 28930.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1876.09 for Qty: 15.81176727789468
# Sell btc @ price: 29933.52 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1883.81 for Qty: -16.27550695402909
# Buy btc @ price: 30659.8 for Qty: 1
# ------
# close position
# Buy eth @ price: 1882.58 for Qty: 16.27550695402909
# Sell btc @ price: 30584.5 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1854.1 for Qty: -16.311941103500352
# Buy btc @ price: 30243.97 for Qty: 1
# ------
# close position
# Buy eth @ price: 1866.46 for Qty: 16.311941103500352
# Sell btc @ price: 30452.74 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1855.37 for Qty: -16.242465074163505
# Buy btc @ price: 30135.63 for Qty: 1
# ------
# close position
# Buy eth @ price: 1919.08 for Qty: 16.242465074163505
# Sell btc @ price: 30429.36 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1968.17 for Qty: -15.785546980189718
# Buy btc @ price: 31068.64 for Qty: 1
# ------
# close position
# Buy eth @ price: 1941.28 for Qty: 15.785546980189718
# Sell btc @ price: 30868.71 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1917.66 for Qty: -16.08559956196386
# Buy btc @ price: 30846.55 for Qty: 1
# ------
# close position
# Buy eth @ price: 1887.25 for Qty: 16.08559956196386
# Sell btc @ price: 30294.85 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1865.26 for Qty: -16.16614394853237
# Buy btc @ price: 30153.9 for Qty: 1
# ------
# close position
# Buy eth @ price: 1889.99 for Qty: 16.16614394853237
# Sell btc @ price: 30724.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1883.77 for Qty: -16.203925086793575
# Buy btc @ price: 30524.63 for Qty: 1
# ------
# close position
# Buy eth @ price: 1872.79 for Qty: 16.203925086793575
# Sell btc @ price: 30383.79 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1995.26 for Qty: -15.840626487908782
# Buy btc @ price: 31606.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 2009.25 for Qty: 15.840626487908782
# Sell btc @ price: 31459.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1991.21 for Qty: -15.618011159043999
# Buy btc @ price: 31098.75 for Qty: 1
# ------
# close position
# Buy eth @ price: 1931.18 for Qty: 15.618011159043999
# Sell btc @ price: 30283.12 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1916.23 for Qty: -15.805326082985863
# Buy btc @ price: 30286.65 for Qty: 1
# ------
# close position
# Buy eth @ price: 1908.81 for Qty: 15.805326082985863
# Sell btc @ price: 30174.84 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1908.88 for Qty: -15.754767193328023
# Buy btc @ price: 30073.97 for Qty: 1
# ------
# close position
# Buy eth @ price: 1897.21 for Qty: 15.754767193328023
# Sell btc @ price: 29912.01 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1892.05 for Qty: -15.705710737031264
# Buy btc @ price: 29715.98 for Qty: 1
# ------
# close position
# Buy eth @ price: 1891.59 for Qty: 15.705710737031264
# Sell btc @ price: 29800.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1875.0 for Qty: -15.958394666666667
# Buy btc @ price: 29921.99 for Qty: 1
# ------
# close position
# Buy eth @ price: 1889.13 for Qty: 15.958394666666667
# Sell btc @ price: 30093.12 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1868.35 for Qty: -15.904863088484017
# Buy btc @ price: 29716.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1853.39 for Qty: 15.904863088484017
# Sell btc @ price: 29128.29 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1857.99 for Qty: -15.773164693218515
# Buy btc @ price: 29306.54 for Qty: 1
# ------
# close position
# Buy eth @ price: 1873.19 for Qty: 15.773164693218515
# Sell btc @ price: 29401.93 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1878.48 for Qty: -15.64918257943965
# Buy btc @ price: 29396.52 for Qty: 1
# ------
# close position
# Buy eth @ price: 1857.37 for Qty: 15.64918257943965
# Sell btc @ price: 29247.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1862.11 for Qty: -15.689722948697984
# Buy btc @ price: 29216.0 for Qty: 1
# ------
# close position
# Buy eth @ price: 1852.61 for Qty: 15.689722948697984
# Sell btc @ price: 29412.04 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1841.85 for Qty: -15.827411718716068
# Buy btc @ price: 29151.57 for Qty: 1
# ------
# close position
# Buy eth @ price: 1836.48 for Qty: 15.827411718716068
# Sell btc @ price: 29072.13 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1815.12 for Qty: -15.966613777601482
# Buy btc @ price: 28981.31 for Qty: 1
# ------
# close position
# Buy eth @ price: 1834.87 for Qty: 15.966613777601482
# Sell btc @ price: 29249.13 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1846.78 for Qty: -15.919465667455423
# Buy btc @ price: 29399.91 for Qty: 1
# ------
# close position
# Buy eth @ price: 1828.78 for Qty: 15.919465667455423
# Sell btc @ price: 29228.51 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1807.81 for Qty: -15.892438917806627
# Buy btc @ price: 28730.51 for Qty: 1
# ------
# close position
# Buy eth @ price: 1661.29 for Qty: 15.892438917806627
# Sell btc @ price: 25918.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1673.65 for Qty: -15.652117540211751
# Buy btc @ price: 26196.01 for Qty: 1
# ------
# close position
# Buy eth @ price: 1664.18 for Qty: 15.652117540211751
# Sell btc @ price: 26056.0 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1635.0 for Qty: -15.936488908189041
# Buy btc @ price: 26055.99 for Qty: 1
# ------
# close position
# Buy eth @ price: 1652.9 for Qty: 15.936488908189041
# Sell btc @ price: 26079.99 for Qty: -1
# ------
# long () and short ()
# Sell eth @ price: 1649.89 for Qty: -15.766397963512938
# Buy btc @ price: 26012.98 for Qty: 1
# ------
# close position
# Buy eth @ price: 1706.42 for Qty: 15.766397963512938
# Sell btc @ price: 27261.03 for Qty: -1
# ==================================================
# Starting Value - 100000.00
# Ending   Value - 45441.42
# ==================================================
# (0.8549533547222941, {'OPEN_THRE': 1, 'CLOS_THRE': 0.1, 'period': 30})
