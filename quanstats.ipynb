# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('META')

# show sharpe ratio
qs.stats.sharpe(stock)

# or using extend_pandas() :)
stock.sharpe()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 0.6702202836193921

# %%
qs.plots.snapshot(stock, title='Facebook Performance', show=True)

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance', show=True)

# %%
qs.reports.basic(stock)
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2012-05-21
# End Period          2023-11-27
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   775.49%
# CAGR﹪              13.88%
#
# Sharpe              0.67
# Prob. Sharpe Ratio  98.86%
# Sortino             0.99
# Sortino/√2          0.7
# Omega               1.14
#
# Max Drawdown        -76.74%
# Longest DD Days     811
#
# Gain/Pain Ratio     0.14
# Gain/Pain (1M)      0.75
#
# Payoff Ratio        1.03
# Profit Factor       1.14
# Common Sense Ratio  1.13
# CPC Index           0.62
# Tail Ratio          0.99
# Outlier Win Ratio   3.92
# Outlier Loss Ratio  3.91
#
# MTD                 11.1%
# 3M                  17.23%
# 6M                  27.73%
# YTD                 178.13%
# 1Y                  200.42%
# 3Y (ann.)           5.46%
# 5Y (ann.)           13.68%
# 10Y (ann.)          14.7%
# All-time (ann.)     13.88%
#
# Avg. Drawdown       -5.45%
# Avg. Drawdown Days  33
# Recovery Factor     4.04
# Ulcer Index         0.23
# Serenity Index      0.77
# <h4>Strategy Visualization</h4>
